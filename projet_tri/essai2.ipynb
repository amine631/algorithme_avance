# %% [markdown]
# # Importation des  Bibliothéques

# %%
from numpy import random as rd
from datetime import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Tri à Bulles:

# %%
temps_d = datetime.now()
temps_triBulle = []
tableau=[]


def triBulle (v):
    permut = True
    p=len(a)-1
    while (permut):
        permut=False
        for i in range(0,p):
            if (a[i] > a[i+1]):
                aux=a[i]
                a[i]=a[i+1]
                a[i+1]=aux
                permut=True
        p-=1
    print("le tableau trié",a)
    temps_f = datetime.now()
    temps = temps_f-temps_d
    sec = temps.total_seconds()
    temps_triBulle.append(sec)
    
    
    
borne_inf=10000
borne_sup=50000
pas=5000
for i in range(borne_inf, borne_sup+1, pas):
    tableau.append(i)
    a=rd.randint(100, size=(i))
    pas=len(a)-1
    triBulle(a)
# Out:
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]

# %% [markdown]
# # La courbe de Tri à Bulle:

# %%
plt.figure()
plt.plot(tableau,temps_triBulle,"red")
plt.title("Tri à Bulle")
plt.xlabel("N : Nombre des entiers dans le tableau")
plt.ylabel("Temps nécessaire en seconde ")
plt.grid()

# %% [markdown]
# # Tri par Insertion:

# %%
temps_d = datetime.now()
temps_triInsertion = []
tableau=[]

def triInsertion (v):
    p=len(v)-1
    for i in range(0,p) :
        x = v[i+1]
        j=i
        while((v[j] > x ) and (j>=0) ) :
            v[j+1] = v[j]
            j-= 1
        v[j+1] = x
    print("le tableau trié",v)
    temps_f = datetime.now()
    temps = temps_f-temps_d
    sec = temps.total_seconds()
    temps_triInsertion.append(sec)
    
    
    
    
borne_inf=10000
borne_sup=50000
pas=5000
for i in range(borne_inf, borne_sup+1, pas):
    tableau.append(i)
    a=rd.randint(100, size=(i))
    pas=len(a)-1
    triInsertion(a)
# Out:
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]
# le tableau trié [ 0  0  0 ... 99 99 99]

# %% [markdown]
# # La courbe de Tri par Insertion:

# %%
plt.figure()
plt.plot(tableau,temps_triInsertion,"blue")
plt.title("Tri par Insertion")
plt.xlabel("N : Nombre des entiers dans le tableau")
plt.ylabel("Temps nécessaire en seconde ")
plt.grid()

# %% [markdown]
# # Tri par Selection:

# %%
temps_d= datetime.now()
temps_triSelection = []
tableau=[]

def triSelection(v):
    for i in range(len(v)):
        ind_min = i
        for k in range(i+1,len(v)):
            if (v[k] < v[ind_min]):
                ind_min = k
        aux = v[i]
        v[i]= v[ind_min]
        v[ind_min]=aux
    print("Le tableau trié",v)
    
    temps_f = datetime.now()
    temps = temps_f-temps_d
    sec = temps.total_seconds()
    temps_triSelection.append(sec)
    
    
    
    
borne_inf=10000
borne_sup=50000
pas=5000
for i in range(borne_inf, borne_sup+1, pas):
    tableau.append(i)
    a=rd.randint(100, size=(i))
    pas=len(a)-1
    triSelection(a)
# Out:
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]
# Le tableau trié [ 0  0  0 ... 99 99 99]

# %% [markdown]
# # La courbe de Tri par Selection:

# %%
plt.figure()
plt.plot(tableau,temps_triSelection,"red")
plt.title("Tri par selection")
plt.xlabel("N : Nombre des entiers dans le tableau")
plt.ylabel("Temps nécessaire en seconde ")
plt.grid()

# %% [markdown]
# # Tri Fusion:

# %%
temps_d = datetime.now()
temps_triFusion = []
tableau=[]



def TriFusion(w):
    def triFusion(v):

        if len(v)>1:
            mid = len(v)//2
            left = v[:mid]
            right = v[mid:]

            triFussion(left)
            triFussion(right)

            i=0
            j=0
            k=0
            while i < len(left) and j < len(right):
                if left[i] <= right[j]:
                    v[k]=left[i]
                    i=i+1
                else:
                    v[k]=right[j]
                    j=j+1
                k=k+1

            while i < len(left):
                v[k]=left[i]
                i=i+1
                k=k+1

            while j < len(right):
                v[k]=right[j]
                j=j+1
                k=k+1
    temps_f = datetime.now() # prendre le temps apres execution de l'algo
    temps = temps_f-temps_d # difference entre temp de début et temp de fin
    sec = temps.total_seconds() # conversion du temp de difference en seconde
    temps_triFusion.append(float(sec))

    
    
    
borne_inf=10000
borne_sup=100000
pas=10000
for i in range(borne_inf, borne_sup+1, pas):
    tableau.append(i)
    a=rd.randint(100, size=(i))
    pas=len(a)-1
    TriFusion(a)
    print("le tableau trié",a)
# Out:
# le tableau trié [28 55 38 ... 87 63 19]
# le tableau trié [93 12 81 ...  2 82 30]
# le tableau trié [82 19 49 ... 76 20 68]
# le tableau trié [18  8 35 ... 87  8 94]
# le tableau trié [13 24 59 ... 61 42 37]
# le tableau trié [11 19 73 ... 64 49 96]
# le tableau trié [85 82  3 ... 88  8 81]
# le tableau trié [96 77 77 ... 60 78 93]
# le tableau trié [35 29  3 ... 42 53  0]
# le tableau trié [82 75 51 ... 20 83 65]

# %% [markdown]
# # La courbe de Tri Fusion:

# %%
plt.figure(figsize=(12,10))
plt.plot(tableau,temps_triFusion,"blue")
plt.title("Tri Fusion")
plt.xlabel("N : Nombre des entiers dans le tableau")
plt.ylabel("Temps CPU en seconde ")
plt.grid()
plt.show()

# %% [markdown]
# # Tri Rapide:

# %%
temps_d = datetime.now()
temps_triRapide = []
tableau=[]



def TriRapide(v,fin,debut=0):

    def triRapide(v,fin,debut=0):

        def division(v, debut, fin):
            i = (debut-1)		 
            pivot = v[fin]	 

            for j in range(debut, fin):

                if v[j] <= pivot:

                    i = i+1
                    v[i], v[j] = v[j], v[i]

            v[i+1], v[fin] = v[fin], v[i+1]
            return (i+1)

        if len(v) == 1:
            return v
        if debut < fin:
            pivot = division(v, debut, fin)
            triRapide(v, debut, pivot-1)
            triRapide(v, pivot+1, fin)
    temps_f = datetime.now() # prendre le temps apres execution de l'algo
    temps = temps_f-temps_d # difference entre temp de début et temp de fin
    sec = temps.total_seconds()# conversion du temp de difference en seconde
    temps_triRapide.append(float(sec))
    
    
    
borne_inf=10000
borne_sup=100000
pas=10000
for i in range(borne_inf, borne_sup+1, pas):
    tableau.append(i)
    a=rd.randint(100, size=(i))
    pas=len(a)-1
    TriRapide(a,pas)
    print("le tableau trié",a)
# Out:
# le tableau trié [29 40 42 ... 38 16 28]
# le tableau trié [62 50 83 ... 44 15 50]
# le tableau trié [10 15 51 ... 57 57 77]
# le tableau trié [27  5 80 ... 12  8 73]
# le tableau trié [36 52 45 ... 37 56 32]
# le tableau trié [71  0 62 ... 72 96 29]
# le tableau trié [23  5  6 ... 23  3 99]
# le tableau trié [57 68 51 ... 14 15 73]
# le tableau trié [ 0 82  7 ... 41 63 81]
# le tableau trié [94 38 74 ... 55  5 76]

# %% [markdown]
# # La courbe de Tri Rapide:

# %%
plt.figure(figsize=(12,10))
plt.plot(tableau,temps_triRapide,"blue")
plt.title("Tri Rapide")
plt.xlabel("N : Nombre des entiers dans le tableau")
plt.ylabel("Temps CPU en seconde ")
plt.grid()
plt.show()
